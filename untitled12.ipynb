# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import sent_tokenize
text="""A blockchain is a distributed ledger with growing lists of records (blocks) that are securely linked together via cryptographic hashes.[1][2][3][4] Each block contains a cryptographic hash of the previous block, a timestamp, and transaction data (generally represented as a Merkle tree, where data nodes are represented by leaves). Since each block contains information about the previous block, they effectively form a chain (compare linked list data structure), with each additional block linking to the ones before it."""
tokenized_text=sent_tokenize(text)
print(tokenized_text)
# Out:
# ['A blockchain is a distributed ledger with growing lists of records (blocks) that are securely linked together via cryptographic hashes.', '[1][2][3][4] Each block contains a cryptographic hash of the previous block, a timestamp, and transaction data (generally represented as a Merkle tree, where data nodes are represented by leaves).', 'Since each block contains information about the previous block, they effectively form a chain (compare linked list data structure), with each additional block linking to the ones before it.']

# %%
#word token
from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(text)
print(tokenized_word)
# Out:
# ['A', 'blockchain', 'is', 'a', 'distributed', 'ledger', 'with', 'growing', 'lists', 'of', 'records', '(', 'blocks', ')', 'that', 'are', 'securely', 'linked', 'together', 'via', 'cryptographic', 'hashes', '.', '[', '1', ']', '[', '2', ']', '[', '3', ']', '[', '4', ']', 'Each', 'block', 'contains', 'a', 'cryptographic', 'hash', 'of', 'the', 'previous', 'block', ',', 'a', 'timestamp', ',', 'and', 'transaction', 'data', '(', 'generally', 'represented', 'as', 'a', 'Merkle', 'tree', ',', 'where', 'data', 'nodes', 'are', 'represented', 'by', 'leaves', ')', '.', 'Since', 'each', 'block', 'contains', 'information', 'about', 'the', 'previous', 'block', ',', 'they', 'effectively', 'form', 'a', 'chain', '(', 'compare', 'linked', 'list', 'data', 'structure', ')', ',', 'with', 'each', 'additional', 'block', 'linking', 'to', 'the', 'ones', 'before', 'it', '.']

# %%
# freq dist
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_word)
print(fdist)

fdist.most_common(3)
# Out:
# <FreqDist with 66 samples and 103 outcomes>
# [('a', 5), ('block', 5), (',', 5)]

# %%
#Frequency Distribution Plot
import matplotlib.pyplot as plt
fdist.plot(30,cumulative = False)
plt.show()

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# {'hers', 'll', 'no', 'down', "aren't", "it's", 'for', 'myself', 'those', 'been', 'by', 'when', 'how', 'where', 'needn', 'above', 'to', 'an', 'their', 'at', 'few', 'all', 'most', 'same', 'against', 'is', 't', 'didn', 'during', 'then', 'don', "hasn't", 'or', 'between', "needn't", 'd', 'now', 'both', 'just', "wouldn't", 'herself', 'why', 'ain', 'won', 'until', 'some', 'whom', 'ours', 'i', 'has', 'ourselves', 'that', 'had', "doesn't", 'but', 'mustn', 'doing', 'over', "you'd", 'not', 'once', 'so', 'about', 'what', "mustn't", 'while', 'they', 'you', 'shouldn', 'very', 'our', 'couldn', 'aren', "you've", 'do', 'wouldn', 'any', 'did', "don't", 'of', 'which', "isn't", "you'll", "won't", "that'll", 'o', 'have', 'this', 'your', 'on', 'am', 'after', 'will', "should've", 'are', 'than', 'below', 'such', 'hadn', 'does', 'under', 'she', "you're", 'theirs', 'and', "weren't", "mightn't", 'each', 'as', 'again', 'we', "hadn't", 'nor', 'because', 'shan', 'its', 'themselves', "shouldn't", 'with', 'through', 'his', "she's", "wasn't", 'who', 'off', 'weren', 'm', 's', 'the', 'haven', 'before', 'there', "didn't", 've', 'into', 'out', 'my', 'y', 'himself', 'from', 'can', 'hasn', 'him', 'were', 'only', "shan't", 'it', 'other', 'them', 'isn', 'having', 'be', "couldn't", 'more', 'was', 'me', 'wasn', 'yours', 'yourself', 'a', 'further', 'up', 'too', 'should', 'itself', 'own', 'in', 'ma', 'mightn', 'if', "haven't", 'these', 'he', 're', 'here', 'yourselves', 'doesn', 'her', 'being'}
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#removing stopword
filtered_sent = []
for w in tokenized_word:
  if w not in stop_words:
    filtered_sent.append(w)
print("Tokenized Word:",tokenized_word)
print("Filtered Word:",filtered_sent)
# Out:
# Tokenized Word: ['A', 'blockchain', 'is', 'a', 'distributed', 'ledger', 'with', 'growing', 'lists', 'of', 'records', '(', 'blocks', ')', 'that', 'are', 'securely', 'linked', 'together', 'via', 'cryptographic', 'hashes', '.', '[', '1', ']', '[', '2', ']', '[', '3', ']', '[', '4', ']', 'Each', 'block', 'contains', 'a', 'cryptographic', 'hash', 'of', 'the', 'previous', 'block', ',', 'a', 'timestamp', ',', 'and', 'transaction', 'data', '(', 'generally', 'represented', 'as', 'a', 'Merkle', 'tree', ',', 'where', 'data', 'nodes', 'are', 'represented', 'by', 'leaves', ')', '.', 'Since', 'each', 'block', 'contains', 'information', 'about', 'the', 'previous', 'block', ',', 'they', 'effectively', 'form', 'a', 'chain', '(', 'compare', 'linked', 'list', 'data', 'structure', ')', ',', 'with', 'each', 'additional', 'block', 'linking', 'to', 'the', 'ones', 'before', 'it', '.']
# Filtered Word: ['A', 'blockchain', 'distributed', 'ledger', 'growing', 'lists', 'records', '(', 'blocks', ')', 'securely', 'linked', 'together', 'via', 'cryptographic', 'hashes', '.', '[', '1', ']', '[', '2', ']', '[', '3', ']', '[', '4', ']', 'Each', 'block', 'contains', 'cryptographic', 'hash', 'previous', 'block', ',', 'timestamp', ',', 'transaction', 'data', '(', 'generally', 'represented', 'Merkle', 'tree', ',', 'data', 'nodes', 'represented', 'leaves', ')', '.', 'Since', 'block', 'contains', 'information', 'previous', 'block', ',', 'effectively', 'form', 'chain', '(', 'compare', 'linked', 'list', 'data', 'structure', ')', ',', 'additional', 'block', 'linking', 'ones', '.']

# %%
import nltk
nltk.download('punkt')

#sentence token
from nltk.tokenize import sent_tokenize
text="""A blockchain is a distributed ledger with growing lists of records (blocks) that are securely linked together via cryptographic hashes.[1][2][3][4] Each block contains a cryptographic hash of the previous block, a timestamp, and transaction data (generally represented as a Merkle tree, where data nodes are represented by leaves). Since each block contains information about the previous block, they effectively form a chain (compare linked list data structure), with each additional block linking to the ones before it."""
tokenized_text=sent_tokenize(text)
print(tokenized_text)

#word token
from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(text)
print(tokenized_word)

# freq dist
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_word)
print(fdist)

fdist.most_common(3)

#Frequency Distribution Plot
import matplotlib.pyplot as plt
fdist.plot(30,cumulative = False)
plt.show()

nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)

#removing stopword
filtered_sent = []
for w in tokenized_word:
  if w not in stop_words:
    filtered_sent.append(w)
print("Tokenized Word:",tokenized_word)
print("Filtered Word:",filtered_sent)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['A blockchain is a distributed ledger with growing lists of records (blocks) that are securely linked together via cryptographic hashes.', '[1][2][3][4] Each block contains a cryptographic hash of the previous block, a timestamp, and transaction data (generally represented as a Merkle tree, where data nodes are represented by leaves).', 'Since each block contains information about the previous block, they effectively form a chain (compare linked list data structure), with each additional block linking to the ones before it.']
# ['A', 'blockchain', 'is', 'a', 'distributed', 'ledger', 'with', 'growing', 'lists', 'of', 'records', '(', 'blocks', ')', 'that', 'are', 'securely', 'linked', 'together', 'via', 'cryptographic', 'hashes', '.', '[', '1', ']', '[', '2', ']', '[', '3', ']', '[', '4', ']', 'Each', 'block', 'contains', 'a', 'cryptographic', 'hash', 'of', 'the', 'previous', 'block', ',', 'a', 'timestamp', ',', 'and', 'transaction', 'data', '(', 'generally', 'represented', 'as', 'a', 'Merkle', 'tree', ',', 'where', 'data', 'nodes', 'are', 'represented', 'by', 'leaves', ')', '.', 'Since', 'each', 'block', 'contains', 'information', 'about', 'the', 'previous', 'block', ',', 'they', 'effectively', 'form', 'a', 'chain', '(', 'compare', 'linked', 'list', 'data', 'structure', ')', ',', 'with', 'each', 'additional', 'block', 'linking', 'to', 'the', 'ones', 'before', 'it', '.']
# <FreqDist with 66 samples and 103 outcomes>
# {'hers', 'll', 'no', 'down', "aren't", "it's", 'for', 'myself', 'those', 'been', 'by', 'when', 'how', 'where', 'needn', 'above', 'to', 'an', 'their', 'at', 'few', 'all', 'most', 'same', 'against', 'is', 't', 'didn', 'during', 'then', 'don', "hasn't", 'or', 'between', "needn't", 'd', 'now', 'both', 'just', "wouldn't", 'herself', 'why', 'ain', 'won', 'until', 'some', 'whom', 'ours', 'i', 'has', 'ourselves', 'that', 'had', "doesn't", 'but', 'mustn', 'doing', 'over', "you'd", 'not', 'once', 'so', 'about', 'what', "mustn't", 'while', 'they', 'you', 'shouldn', 'very', 'our', 'couldn', 'aren', "you've", 'do', 'wouldn', 'any', 'did', "don't", 'of', 'which', "isn't", "you'll", "won't", "that'll", 'o', 'have', 'this', 'your', 'on', 'am', 'after', 'will', "should've", 'are', 'than', 'below', 'such', 'hadn', 'does', 'under', 'she', "you're", 'theirs', 'and', "weren't", "mightn't", 'each', 'as', 'again', 'we', "hadn't", 'nor', 'because', 'shan', 'its', 'themselves', "shouldn't", 'with', 'through', 'his', "she's", "wasn't", 'who', 'off', 'weren', 'm', 's', 'the', 'haven', 'before', 'there', "didn't", 've', 'into', 'out', 'my', 'y', 'himself', 'from', 'can', 'hasn', 'him', 'were', 'only', "shan't", 'it', 'other', 'them', 'isn', 'having', 'be', "couldn't", 'more', 'was', 'me', 'wasn', 'yours', 'yourself', 'a', 'further', 'up', 'too', 'should', 'itself', 'own', 'in', 'ma', 'mightn', 'if', "haven't", 'these', 'he', 're', 'here', 'yourselves', 'doesn', 'her', 'being'}
# Tokenized Word: ['A', 'blockchain', 'is', 'a', 'distributed', 'ledger', 'with', 'growing', 'lists', 'of', 'records', '(', 'blocks', ')', 'that', 'are', 'securely', 'linked', 'together', 'via', 'cryptographic', 'hashes', '.', '[', '1', ']', '[', '2', ']', '[', '3', ']', '[', '4', ']', 'Each', 'block', 'contains', 'a', 'cryptographic', 'hash', 'of', 'the', 'previous', 'block', ',', 'a', 'timestamp', ',', 'and', 'transaction', 'data', '(', 'generally', 'represented', 'as', 'a', 'Merkle', 'tree', ',', 'where', 'data', 'nodes', 'are', 'represented', 'by', 'leaves', ')', '.', 'Since', 'each', 'block', 'contains', 'information', 'about', 'the', 'previous', 'block', ',', 'they', 'effectively', 'form', 'a', 'chain', '(', 'compare', 'linked', 'list', 'data', 'structure', ')', ',', 'with', 'each', 'additional', 'block', 'linking', 'to', 'the', 'ones', 'before', 'it', '.']
# Filtered Word: ['A', 'blockchain', 'distributed', 'ledger', 'growing', 'lists', 'records', '(', 'blocks', ')', 'securely', 'linked', 'together', 'via', 'cryptographic', 'hashes', '.', '[', '1', ']', '[', '2', ']', '[', '3', ']', '[', '4', ']', 'Each', 'block', 'contains', 'cryptographic', 'hash', 'previous', 'block', ',', 'timestamp', ',', 'transaction', 'data', '(', 'generally', 'represented', 'Merkle', 'tree', ',', 'data', 'nodes', 'represented', 'leaves', ')', '.', 'Since', 'block', 'contains', 'information', 'previous', 'block', ',', 'effectively', 'form', 'chain', '(', 'compare', 'linked', 'list', 'data', 'structure', ')', ',', 'additional', 'block', 'linking', 'ones', '.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Edit Distance
def editDistDP(str1, str2, m, n):
  # Create a table to store results of subproblems
  dp = [[0 for x in range(n + 1)] for x in range(m + 1)]


  # Fill d[][] in bottom up manner
  for i in range(m + 1):
    for j in range(n + 1):


      # If first string is empty, only option is to
      # insert all characters of second string
      if i == 0:
        dp[i][j] = j # Min. operations = j


      # If second string is empty, only option is to
      # remove all characters of second string
      elif j == 0:
        dp[i][j] = i # Min. operations = i


      # If last characters are same, ignore last char
      # and recur for remaining string
      elif str1[i-1] == str2[j-1]:
        dp[i][j] = dp[i-1][j-1]


      # If last character are different, consider all
      # possibilities and find minimum
      else:
        dp[i][j] = 1 + min(dp[i][j-1],   # Insert
                dp[i-1][j],  # Remove
                dp[i-1][j-1]) # Replace


  return dp[m][n]


# Driver code
str2 = "true"
str1 = "false"


print(editDistDP(str1, str2, len(str1), len(str2)))
# Out:
# 4

# %%
from nltk.tokenize import sent_tokenize
text="""A cryptocurrency is a digital currency, which is an alternative form of payment created using encryption algorithms. The use of encryption technologies means that cryptocurrencies function both as a currency and as a virtual accounting system. To use cryptocurrencies, you need a cryptocurrency wallet."""
tokenized_text=sent_tokenize(text)
print(tokenized_text)
# Out:
# ['A cryptocurrency is a digital currency, which is an alternative form of payment created using encryption algorithms.', 'The use of encryption technologies means that cryptocurrencies function both as a currency and as a virtual accounting system.', 'To use cryptocurrencies, you need a cryptocurrency wallet.']

# %%
#word token
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['A', 'cryptocurrency', 'is', 'a', 'digital', 'currency', ',', 'which', 'is', 'an', 'alternative', 'form', 'of', 'payment', 'created', 'using', 'encryption', 'algorithms', '.', 'The', 'use', 'of', 'encryption', 'technologies', 'means', 'that', 'cryptocurrencies', 'function', 'both', 'as', 'a', 'currency', 'and', 'as', 'a', 'virtual', 'accounting', 'system', '.', 'To', 'use', 'cryptocurrencies', ',', 'you', 'need', 'a', 'cryptocurrency', 'wallet', '.']

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize


ps = PorterStemmer()


stemmed_words=[]
for w in tokenized_word:
    stemmed_words.append(ps.stem(w))


print("Filtered Sentence:",tokenized_word)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['A', 'cryptocurrency', 'is', 'a', 'digital', 'currency', ',', 'which', 'is', 'an', 'alternative', 'form', 'of', 'payment', 'created', 'using', 'encryption', 'algorithms', '.', 'The', 'use', 'of', 'encryption', 'technologies', 'means', 'that', 'cryptocurrencies', 'function', 'both', 'as', 'a', 'currency', 'and', 'as', 'a', 'virtual', 'accounting', 'system', '.', 'To', 'use', 'cryptocurrencies', ',', 'you', 'need', 'a', 'cryptocurrency', 'wallet', '.']
# Stemmed Sentence: ['a', 'cryptocurr', 'is', 'a', 'digit', 'currenc', ',', 'which', 'is', 'an', 'altern', 'form', 'of', 'payment', 'creat', 'use', 'encrypt', 'algorithm', '.', 'the', 'use', 'of', 'encrypt', 'technolog', 'mean', 'that', 'cryptocurr', 'function', 'both', 'as', 'a', 'currenc', 'and', 'as', 'a', 'virtual', 'account', 'system', '.', 'to', 'use', 'cryptocurr', ',', 'you', 'need', 'a', 'cryptocurr', 'wallet', '.']

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
import nltk


from nltk.stem.porter import *
p_stemmer = PorterStemmer()
words = ['run','runner','running','ran','runs','easily','fairly']
for word in words:
    print(word+' --> '+p_stemmer.stem(word))
# Out:
# run --> run
# runner --> runner
# running --> run
# ran --> ran
# runs --> run
# easily --> easili
# fairly --> fairli
